# %%
import urllib.request
from bs4 import BeautifulSoup
import time
import re

url = 'http://www.boxofficemojo.com/yearly/chart/?view2=worldwide&yr=2017'  
html = urllib.request.urlopen(url)    
bsObj = BeautifulSoup(html,'lxml-xml')
bsObj
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
# <HEAD>
# <TITLE>2017 Yearly Box Office Results - Box Office Mojo</TITLE>
# <META CONTENT="2017, year, yearly, box, office, result, list, movie, movies, listing, listings, top movies, all time, film" NAME="keywords">
# <META CONTENT="Yearly box office results for 2017." NAME="description">
# <link charset="utf-8" href="/css/mojo.css?1" media="screen" rel="stylesheet" title="no title" type="text/css">
# <link charset="utf-8" href="/css/mojo.css?1" media="print" rel="stylesheet" title="no title" type="text/css"/>
# <body>
# <iframe frameborder="0" height="1" id="sis_pixel_sitewide" marginheight="0" marginwidth="0" style="display: none;" width="1"/>
# <script>
#     setTimeout(function(){
#         try{
#             //sis3.0 pixel
#             var cacheBust = Math.random() * 10000000000000000,
# ...

# %%
href_list=bsObj.findAll('a', attrs={'href': re.compile(r"movies")})
href_list
# Out:
# [<a href="/movies/?id=marvel2017b.htm">#1 Movie: 'Black Panther'</a>,
#  <a href="/movies/?id=starwars8.htm"><b>Star Wars: The Last Jedi</b></a>,
#  <a href="/movies/?id=beautyandthebeast2017.htm"><b>Beauty and the Beast (2017)</b></a>,
#  <a href="/movies/?id=furious8.htm"><b>The Fate of the Furious</b></a>,
#  <a href="/movies/?id=despicableme3.htm"><b>Despicable Me 3</b></a>,
#  <a href="/movies/?id=jumanji2016.htm"><b>Jumanji: Welcome to the Jungle</b></a>,
#  <a href="/movies/?id=spiderman2017.htm"><b>Spider-Man: Homecoming</b></a>,
#  <a href="/movies/?id=wolfwarrior2.htm"><b>Wolf Warrior 2</b></a>,
#  <a href="/movies/?id=marvel17a.htm"><b>Guardians of the Galaxy Vol. 2</b></a>,
#  <a href="/movies/?id=marvel2017.htm"><b>Thor: Ragnarok</b></a>,
#  <a href="/movies/?id=wonderwoman.htm"><b>Wonder Woman</b></a>,
#  <a href="/movies/?id=potc5.htm"><b>Pirates of the Caribbean: Dead Men Tell No Tales</b></a>,
#  <a href="/movies/?id=pixar1117.htm"><b>Coco</b></a>,
# ...

# %%
Link=[]
for i in range(1,len(href_list)):
    m=href_list[i].attrs
    x=str(list(m.values())[0])
    y="http://www.boxofficemojo.com"+x
    z=y.replace('id',r'page=intl&country=CH&id')
    Link.append(z)

# %%
td_list=bsObj.find_all('td') 
td_list
# Out:
# [<td valign="center">
#  <font face="Verdana" size="2"><a href="/about/adjuster.htm"><b>Adjuster:</b></a></font>
#  <select name="ticketyr" size="1" style="font-family: Verdana; font-size: 10pt">
#  <option value="0">Actuals</option>
#  <option value="1">Est. Tckts</option>
#  <script language="javascript">
#    for(i=2018; i&gt;=1933; i--) {
#    	document.write('<option value="' + i + '">');
#  	if(i=='0') document.write(' selected');
#  	document.write('&gt;' + i );
#  	if(i=='0') document.write(', $' + '0.00');
#  	document.write('</option>');
#    }
#  </script>
#  <option value="1929">1929</option>
#  <option value="1924">1924</option>
#  <option value="1910">1910</option>
#  </select><input name="Go" style="font-size: 10pt; height: 22" type="submit" value="Go">
#  </input></td>,
#  <td bgcolor="#8b0000" colspan="2"><img border="0" height="5" src="/images/space.gif" width="1"/></td>,
#  <td align="center" valign="top"><br>
#  <h1>2017 WORLDWIDE GROSSES</h1><p/></br></td>,
# ...

# %%
data=[]
for td in td_list:
    l=[]
    for tr in td:
        l.append(tr.string)
    data.append(l)

# %%
import numpy as np
I = list(range(0,10))
data=np.delete(data, I).tolist()

# %%
Rank=[]
Title=[]
Studio=[]
Worldwide=[]
Domestic=[]
Overseas=[]
for i in range(len(data)):
    col=i%8
    x=data[i][0]
    if col==0:
        Rank.append(x)
    elif col==1:
        Title.append(x)
    elif col==2:
        Studio.append(x)
    elif col==3:
        Worldwide.append(x)
    elif col==4:
        Domestic.append(x)
    elif col==6:
        Overseas.append(x)
Rank.pop() 
Title.pop()

# %%
import pandas as pd
dict={'Rank':Rank,
      'Title':Title,
      'Studio':Studio,
      'Worldwide':Worldwide,
      'Domestic':Domestic,
      'Overseas':Overseas,
      'Link':Link}

boxoffice = pd.DataFrame(dict)                   
boxoffice = boxoffice[['Rank', 'Title', 'Studio','Worldwide','Domestic','Overseas','Link']]
boxoffice
# Out:
#     Rank                                              Title    Studio  \
# 0      1                           Star Wars: The Last Jedi        BV
# 1      2                        Beauty and the Beast (2017)        BV
# 2      3                            The Fate of the Furious      Uni.
# 3      4                                    Despicable Me 3      Uni.
# 4      5                     Jumanji: Welcome to the Jungle      Sony
# 5      6                             Spider-Man: Homecoming      Sony
# 6      7                                     Wolf Warrior 2        HC
# 7      8                     Guardians of the Galaxy Vol. 2        BV
# 8      9                                     Thor: Ragnarok        BV
# 9     10                                       Wonder Woman        WB
# 10    11   Pirates of the Caribbean: Dead Men Tell No Tales        BV
# 11    12                                               Coco        BV
# ...

# %%
row=boxoffice.shape[0]
column=boxoffice.shape[1]

# %%
def ReplaceComma(colname):
    '''
    Replace','
    '''
    for i in range(row):
        x=boxoffice[colname][i]
        x=x.replace(',','')
        boxoffice[colname][i]=x

# %%
def DeleteDollar(colname):
    '''
    Delete'$'
    '''
    for i in range(row):
        x=boxoffice[colname][i]
        split1=re.split(r'[$]',x)
        boxoffice[colname][i]=split1[1]

# %%
def TurnToNum(colname):
    '''
    Turn 'k' into number, k=0.01
    '''
    for i in range(row):
        x=boxoffice[colname][i]
        if x!="n/a":
            if x.endswith("k"):
                split1=re.split(r'[k]',x)
                boxoffice[colname][i]=float(float(split1[0])*0.01)

# %%
ReplaceComma("Domestic")
ReplaceComma("Worldwide")
ReplaceComma("Overseas")

# %%
DeleteDollar("Domestic")
DeleteDollar("Worldwide")
DeleteDollar("Overseas")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1076-421facd14a07> in <module>()
#       1 DeleteDollar("Domestic")
#       2 DeleteDollar("Worldwide")
# ----> 3 DeleteDollar("Overseas")
#
# <ipython-input-1073-2608af0bab08> in DeleteDollar(colname)
#       6         x=boxoffice[colname][i]
#       7         split1=re.split(r'[$]',x)
# ----> 8         boxoffice[colname][i]=split1[1]
#
# IndexError: list index out of range

# %%
TurnToNum("Domestic")
TurnToNum("Worldwide")
TurnToNum("Overseas")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1077-e55869702d4a> in <module>()
#       1 TurnToNum("Domestic")
#       2 TurnToNum("Worldwide")
# ----> 3 TurnToNum("Overseas")
#
# <ipython-input-1074-f93640f90331> in TurnToNum(colname)
#       8             if x.endswith("k"):
#       9                 split1=re.split(r'[k]',x)
# ---> 10                 boxoffice[colname][i]=float(float(split1[0])*0.01)
#
# ValueError: could not convert string to float: '$78.1'

# %%
boxoffice.head()
# Out:
#   Rank                           Title Studio Worldwide Domestic Overseas  \
# 0    1        Star Wars: The Last Jedi     BV    1331.2    619.2    712.0
# 1    2     Beauty and the Beast (2017)     BV    1263.5    504.0    759.5
# 2    3         The Fate of the Furious   Uni.    1236.0    226.0   1010.0
# 3    4                 Despicable Me 3   Uni.    1034.8    264.6    770.2
# 4    5  Jumanji: Welcome to the Jungle   Sony     931.1    394.2    536.9
#
#                                                 Link
# 0  http://www.boxofficemojo.com/movies/?page=intl...
# 1  http://www.boxofficemojo.com/movies/?page=intl...
# 2  http://www.boxofficemojo.com/movies/?page=intl...
# 3  http://www.boxofficemojo.com/movies/?page=intl...
# 4  http://www.boxofficemojo.com/movies/?page=intl...

# %%
boxoffice=boxoffice[-boxoffice["Overseas"].isin(['n/a'])]
boxoffice=boxoffice[-boxoffice["Domestic"].isin(['n/a'])]

# %%
#Make sure all columns of numbers are numeric (not strings).
boxoffice.Worldwide =pd.to_numeric(boxoffice.Worldwide, errors='coerce').fillna(0).astype(float)
boxoffice.Domestic =pd.to_numeric(boxoffice.Domestic, errors='coerce').fillna(0).astype(float)
boxoffice.Overseas =pd.to_numeric(boxoffice.Overseas,errors='coerce').fillna(0).astype(float)

# %%
boxoffice.dtypes
# Out:
# Rank          object
# Title         object
# Studio        object
# Worldwide    float64
# Domestic     float64
# Overseas     float64
# Link          object
# dtype: object

# %%
boxoffice.head()
# Out:
#    Rank                                             Title Studio  Worldwide  \
# 2     3                           The Fate of the Furious   Uni.     1236.0
# 3     4                                   Despicable Me 3   Uni.     1034.8
# 10   11  Pirates of the Caribbean: Dead Men Tell No Tales     BV      794.9
# 11   12                                              Coco     BV      745.0
# 15   16                     Transformers: The Last Knight   Par.      605.4
#
#     Domestic  Overseas                                               Link  \
# 2      226.0    1010.0  http://www.boxofficemojo.com/movies/?page=intl...
# 3      264.6     770.2  http://www.boxofficemojo.com/movies/?page=intl...
# 10     172.6     622.3  http://www.boxofficemojo.com/movies/?page=intl...
# 11     208.6     536.4  http://www.boxofficemojo.com/movies/?page=intl...
# 15     130.2     475.3  http://www.boxofficemojo.com/movies/?page=intl...
#
#     Dome_minus_Over
# 2          3.469027
# 3          1.910809
# ...

# %%
boxoffice['Dome_minus_Over']=(boxoffice['Overseas']-boxoffice['Domestic'])/boxoffice['Domestic']
boxoffice.head()
# Out:
#    Rank                                             Title Studio  Worldwide  \
# 2     3                           The Fate of the Furious   Uni.     1236.0
# 3     4                                   Despicable Me 3   Uni.     1034.8
# 10   11  Pirates of the Caribbean: Dead Men Tell No Tales     BV      794.9
# 11   12                                              Coco     BV      745.0
# 15   16                     Transformers: The Last Knight   Par.      605.4
#
#     Domestic  Overseas                                               Link  \
# 2      226.0    1010.0  http://www.boxofficemojo.com/movies/?page=intl...
# 3      264.6     770.2  http://www.boxofficemojo.com/movies/?page=intl...
# 10     172.6     622.3  http://www.boxofficemojo.com/movies/?page=intl...
# 11     208.6     536.4  http://www.boxofficemojo.com/movies/?page=intl...
# 15     130.2     475.3  http://www.boxofficemojo.com/movies/?page=intl...
#
#     Dome_minus_Over
# 2          3.469027
# 3          1.910809
# ...

# %%
boxoffice=boxoffice[(boxoffice['Dome_minus_Over']>1)&(boxoffice['Dome_minus_Over']<60)]
boxoffice.head()
# Out:
#    Rank                                             Title Studio  Worldwide  \
# 2     3                           The Fate of the Furious   Uni.     1236.0
# 3     4                                   Despicable Me 3   Uni.     1034.8
# 10   11  Pirates of the Caribbean: Dead Men Tell No Tales     BV      794.9
# 11   12                                              Coco     BV      745.0
# 15   16                     Transformers: The Last Knight   Par.      605.4
#
#     Domestic  Overseas                                               Link  \
# 2      226.0    1010.0  http://www.boxofficemojo.com/movies/?page=intl...
# 3      264.6     770.2  http://www.boxofficemojo.com/movies/?page=intl...
# 10     172.6     622.3  http://www.boxofficemojo.com/movies/?page=intl...
# 11     208.6     536.4  http://www.boxofficemojo.com/movies/?page=intl...
# 15     130.2     475.3  http://www.boxofficemojo.com/movies/?page=intl...
#
#     Dome_minus_Over
# 2          3.469027
# 3          1.910809
# ...

# %% [markdown]
# Korea:CJ

# %%
selected=set(boxoffice['Studio'])
selected
# Out:
# {'BV',
#  'CJ',
#  'CL',
#  'FUN',
#  'Fox',
#  'GrtIndia',
#  'Par.',
#  'SGem',
#  'STX',
#  'Sony',
#  'Uni.',
#  'WB',
#  'WB (NL)',
#  'WGUSA',
#  'Wein.',
#  'Yash'}

# %%
data=boxoffice[(boxoffice['Studio']=='Amazon')|(boxoffice['Studio']=='BG')|
              (boxoffice['Studio']=='BV')|(boxoffice['Studio']=='Fox')|
              (boxoffice['Studio']=='SGem')|(boxoffice['Studio']=='STX')|
              (boxoffice['Studio']=='Sony')|(boxoffice['Studio']=='Par.')|
              (boxoffice['Studio']=='Uni.')|(boxoffice['Studio']=='WB')|
              (boxoffice['Studio']=='WB (NL)')|(boxoffice['Studio']=='Wein.')]
data=data.reset_index(drop=True) 
data.head()
# Out:
#   Rank                                             Title Studio  Worldwide  \
# 0    3                           The Fate of the Furious   Uni.     1236.0
# 1    4                                   Despicable Me 3   Uni.     1034.8
# 2   11  Pirates of the Caribbean: Dead Men Tell No Tales     BV      794.9
# 3   12                                              Coco     BV      745.0
# 4   16                     Transformers: The Last Knight   Par.      605.4
#
#    Domestic  Overseas                                               Link  \
# 0     226.0    1010.0  http://www.boxofficemojo.com/movies/?page=intl...
# 1     264.6     770.2  http://www.boxofficemojo.com/movies/?page=intl...
# 2     172.6     622.3  http://www.boxofficemojo.com/movies/?page=intl...
# 3     208.6     536.4  http://www.boxofficemojo.com/movies/?page=intl...
# 4     130.2     475.3  http://www.boxofficemojo.com/movies/?page=intl...
#
#    Dome_minus_Over
# 0         3.469027
# 1         1.910809
# ...

# %% [markdown]
# Fifty Shades Darker wasn't on China.

# %%
title=list(boxoffice['Title'])
title
# Out:
# ['The Fate of the Furious',
#  'Despicable Me 3',
#  'Pirates of the Caribbean: Dead Men Tell No Tales',
#  'Coco',
#  'Transformers: The Last Knight',
#  'Kong: Skull Island',
#  'War for the Planet of the Apes',
#  'Kingsman: The Golden Circle',
#  'The Mummy (2017)',
#  'Fifty Shades Darker',
#  'Murder on the Orient Express (2017)',
#  'xXx: The Return of Xander Cage',
#  'The Great Wall',
#  'Resident Evil: The Final Chapter',
#  'Annabelle: Creation',
#  'Ferdinand',
#  'Journey to the West: The Demons Strike Back',
#  'Alien: Covenant',
#  'Valerian and the City of a Thousand Planets',
#  'Geostorm',
#  'Smurfs: The Lost Village',
#  "A Dog's Purpose",
#  'Baywatch',
#  'Ghost in the Shell (2017)',
#  'Duckweed',
#  'King Arthur: Legend of the Sword',
#  'The Foreigner',
#  'Baahubali 2: The Conclusion',
#  'Buddies in India',
#  'Leap!',
#  'Railroad Tigers',
#  'Life (2017)',
#  'Tiger Zinda Hai',
#  'A Taxi Driver',
#  'One Piece Film: Gold',
#  'Confidential Assignment',
# ...

# %%
data['Link'][13]='http://www.boxofficemojo.com/movies/?page=intl&country=CH&id=residentevil6.htm'
Chinese=[]
for i in range(len(data)):
    url=data['Link'][i]
    html = urllib.request.urlopen(url)    
    bsObj = BeautifulSoup(html,'lxml-xml')
    list1=bsObj.findAll('b')
    x=list1[14].text
    Chinese.append(x)
# Out:
# C:\Users\qxzhao\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Chinese
# Out:
# ['$392,807,017',
#  '$158,171,566',
#  '$172,277,290',
#  '$189,226,296',
#  '$228,842,508',
#  '$168,188,002',
#  '$112,372,211',
#  '$116,685,716',
#  '$91,707,392',
#  'Australia',
#  '$35,448,563',
#  '$164,066,583',
#  '$170,962,106',
#  '$159,548,686',
#  'Australia',
#  '$27,148,725',
#  '$239,553,888',
#  '$45,963,187',
#  '$62,073,823',
#  '$65,667,015',
#  '$25,558,593',
#  '$88,226,996',
#  'Australia',
#  '$29,327,947',
#  '$8,353,642',
#  '$81,205,559',
#  'China',
#  '$19,881,127']

# %%
data['ChineseBoxOffice']=Chinese
data
# Out:
#    Rank                                             Title   Studio  Worldwide  \
# 0     3                           The Fate of the Furious     Uni.     1236.0
# 1     4                                   Despicable Me 3     Uni.     1034.8
# 2    11  Pirates of the Caribbean: Dead Men Tell No Tales       BV      794.9
# 3    12                                              Coco       BV      745.0
# 4    16                     Transformers: The Last Knight     Par.      605.4
# 5    17                                Kong: Skull Island       WB      566.7
# 6    20                    War for the Planet of the Apes      Fox      490.7
# 7    21                       Kingsman: The Golden Circle      Fox      410.9
# 8    22                                  The Mummy (2017)     Uni.      409.2
# 9    24                               Fifty Shades Darker     Uni.      381.1
# 10   27               Murder on the Orient Express (2017)      Fox      350.5
# ...

# %%
data['ChineseBoxOffice'][26]='$5,770,423'
data
# Out:
# C:\Users\qxzhao\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    Rank                                             Title   Studio  Worldwide  \
# 0     3                           The Fate of the Furious     Uni.     1236.0
# 1     4                                   Despicable Me 3     Uni.     1034.8
# 2    11  Pirates of the Caribbean: Dead Men Tell No Tales       BV      794.9
# 3    12                                              Coco       BV      745.0
# 4    16                     Transformers: The Last Knight     Par.      605.4
# 5    17                                Kong: Skull Island       WB      566.7
# 6    20                    War for the Planet of the Apes      Fox      490.7
# ...

# %%
data=data[-data['ChineseBoxOffice'].isin(['Australia'])]
data=data.reset_index(drop=True) 
data
# Out:
#    Rank                                             Title Studio  Worldwide  \
# 0     3                           The Fate of the Furious   Uni.     1236.0
# 1     4                                   Despicable Me 3   Uni.     1034.8
# 2    11  Pirates of the Caribbean: Dead Men Tell No Tales     BV      794.9
# 3    12                                              Coco     BV      745.0
# 4    16                     Transformers: The Last Knight   Par.      605.4
# 5    17                                Kong: Skull Island     WB      566.7
# 6    20                    War for the Planet of the Apes    Fox      490.7
# 7    21                       Kingsman: The Golden Circle    Fox      410.9
# 8    22                                  The Mummy (2017)   Uni.      409.2
# 9    27               Murder on the Orient Express (2017)    Fox      350.5
# 10   28                    xXx: The Return of Xander Cage   Par.      346.1
# ...

# %%
row=data.shape[0]
column=data.shape[1]

# %%
for i in range(row):
    x=data['ChineseBoxOffice'][i]
    y=re.split(r'[$]',x)
    data['ChineseBoxOffice'][i]=z[1]
# Out:
# C:\Users\qxzhao\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
data['ChineseBoxOffice']=data['ChineseBoxOffice'].str.replace(",","")

# %%
data.ChineseBoxOffice =pd.to_numeric(data.ChineseBoxOffice, errors='coerce').fillna(0).astype(float)
data.ChineseBoxOffice=data.ChineseBoxOffice/100000

# %%
data
# Out:
#    Rank                                             Title Studio  Worldwide  \
# 0     3                           The Fate of the Furious   Uni.     1236.0
# 1     4                                   Despicable Me 3   Uni.     1034.8
# 2    11  Pirates of the Caribbean: Dead Men Tell No Tales     BV      794.9
# 3    12                                              Coco     BV      745.0
# 4    16                     Transformers: The Last Knight   Par.      605.4
# 5    17                                Kong: Skull Island     WB      566.7
# 6    20                    War for the Planet of the Apes    Fox      490.7
# 7    21                       Kingsman: The Golden Circle    Fox      410.9
# 8    22                                  The Mummy (2017)   Uni.      409.2
# 9    27               Murder on the Orient Express (2017)    Fox      350.5
# 10   28                    xXx: The Return of Xander Cage   Par.      346.1
# ...

# %%
data['Domes_minus_China']=data['ChineseBoxOffice']-data['ChineseBoxOffice']
data
# Out:
#    Rank                                             Title Studio  Worldwide  \
# 0     3                           The Fate of the Furious   Uni.     1236.0
# 1     4                                   Despicable Me 3   Uni.     1034.8
# 2    11  Pirates of the Caribbean: Dead Men Tell No Tales     BV      794.9
# 3    12                                              Coco     BV      745.0
# 4    16                     Transformers: The Last Knight   Par.      605.4
# 5    17                                Kong: Skull Island     WB      566.7
# 6    20                    War for the Planet of the Apes    Fox      490.7
# 7    21                       Kingsman: The Golden Circle    Fox      410.9
# 8    22                                  The Mummy (2017)   Uni.      409.2
# 9    27               Murder on the Orient Express (2017)    Fox      350.5
# 10   28                    xXx: The Return of Xander Cage   Par.      346.1
# ...
