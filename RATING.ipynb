# %%
import lxml.html as lx
import pandas as pd
import requests
import requests_cache
import requests
import requests_ftp
import requests_cache
import lxml
from bs4 import BeautifulSoup
from collections import Counter
from matplotlib import pyplot as plt
import pandas as pd
plt.style.use('ggplot')
requests_cache.install_cache('coll_cache')
# %matplotlib inline
import re

# %%
history
# Out:
# IMDb.to_csv("Rating.csv",index=False,sep=',')
# import lxml.html as lx
# import pandas as pd
# import requests
# import requests_cache
# import requests
# import requests_ftp
# import requests_cache
# import lxml
# from bs4 import BeautifulSoup
# from collections import Counter
# from matplotlib import pyplot as plt
# import pandas as pd
# plt.style.use('ggplot')
# requests_cache.install_cache('coll_cache')
# %matplotlib inline
# import re
# def myfun(urlbase):
#     #urlbase = "https://www.the-numbers.com/person/25200401-D-J-Caruso#tab=summary"
#     want1= requests.get(urlbase)
#     want2 =want1.text
#     want3 =BeautifulSoup(want2,'lxml-xml')
#     want4=want3.find_all(name='span',attrs={'itemprop':'ratingValue'})
#     want5=want4[0].text
#     want6=want3.find_all(name='span',attrs={'class':'subText'})
#     want7=want6[2].text.strip()
#     want8=re.split(r"\n",want7)
#     return want8,want5
# link=["http://www.imdb.com/title/tt1293847/",
#       "http://www.imdb.com/title/tt1981128/",
#       "http://www.imdb.com/title/tt4630562/",
#       "http://www.imdb.com/title/tt2345759/",
#       "http://www.imdb.com/title/tt3371366/?ref_=fn_al_tt_1",
#       "http://www.imdb.com/title/tt1790809/?ref_=fn_al_tt_1",
#       "http://www.imdb.com/title/tt1753383/?ref_=fn_al_tt_1"]
# Popularity=[]
# Rate=[]
# for l in link:
#     x=myfun(l)
#     p=x[0][0]
#     r=x[1]
#     Popularity.append(p)
#     Rate.append(r)
# Name=["xXx: Return of Xander Cage",
#       "Geostorm",
#       "The Fate of the Furious",
#       "The Mummy",
#       "Transformers: The Last Knight",
#       "Pirates of the Caribbean: Dead Men Tell No Tales",
#       "A Dog’s Purpose"]
# dict={'Name':Name,
#       'Popularity':Popularity,
#       'Rate':Rate}
# IMDb=pd.DataFrame(dict)
# IMDb
# IMDb.to_csv("Rating.csv",index=False,sep=',')
# import lxml.html as lx
# import pandas as pd
# import requests
# import requests_cache
# import requests
# import requests_ftp
# import requests_cache
# import lxml
# from bs4 import BeautifulSoup
# from collections import Counter
# from matplotlib import pyplot as plt
# import pandas as pd
# plt.style.use('ggplot')
# requests_cache.install_cache('coll_cache')
# %matplotlib inline
# import re
# '''
# 伪装浏览器
#
# 对于一些需要登录的网站，如果不是从浏览器发出的请求，则得不到响应。
# 所以，我们需要将爬虫程序发出的请求伪装成浏览器正规军。
# 具体实现：自定义网页请求报头。
# '''
#
# #实例二：依然爬取豆瓣，采用伪装浏览器的方式
#
# import urllib.request
#
# #定义保存函数
# def saveFile(data):
#     path = "E:\\projects\\Spider\\02_douban.out"
#     f = open(path,'wb')
#     f.write(data)
#     f.close()
#
# #网址
# url = "https://www.douban.com/"
# headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) '
#                         'Chrome/51.0.2704.63 Safari/537.36'}
# req = urllib.request.Request(url=url,headers=headers)
#
# res = urllib.request.urlopen(req)
#
# data = res.read()
#
# #也可以把爬取的内容保存到文件中
# saveFile(data)
#
# data = data.decode('utf-8')
# #打印抓取的内容
# print(data)
#
#
# #打印爬取网页的各类信息
# print(type(res))
# print(res.geturl())
# print(res.info())
# print(res.getcode())
# IMDb.to_csv("Rating.csv",index=False,sep=',')
# Popularity
# history
# import lxml.html as lx
# import pandas as pd
# import requests
# import requests_cache
# import requests
# import requests_ftp
# import requests_cache
# import lxml
# from bs4 import BeautifulSoup
# from collections import Counter
# from matplotlib import pyplot as plt
# import pandas as pd
# plt.style.use('ggplot')
# requests_cache.install_cache('coll_cache')
# %matplotlib inline
# import re
# def myfun(urlbase):
#     #urlbase = "https://www.the-numbers.com/person/25200401-D-J-Caruso#tab=summary"
#     want1= requests.get(urlbase)
#     want2 =want1.text
#     want3 =BeautifulSoup(want2,'lxml-xml')
#     want4=want3.find_all(name='span',attrs={'itemprop':'ratingValue'})
#     want5=want4[0].text
#     want6=want3.find_all(name='span',attrs={'class':'subText'})
#     want7=want6[2].text.strip()
#     want8=re.split(r"\n",want7)
#     return want8,want5
# link=["http://www.imdb.com/title/tt1293847/",
#       "http://www.imdb.com/title/tt1981128/",
#       "http://www.imdb.com/title/tt4630562/",
#       "http://www.imdb.com/title/tt2345759/",
#       "http://www.imdb.com/title/tt3371366/?ref_=fn_al_tt_1",
#       "http://www.imdb.com/title/tt1790809/?ref_=fn_al_tt_1",
#       "http://www.imdb.com/title/tt1753383/?ref_=fn_al_tt_1"]
# Popularity=[]
# Rate=[]
# for l in link:
#     x=myfun(l)
#     p=x[0][0]
#     r=x[1]
#     Popularity.append(p)
#     Rate.append(r)
# Name=["xXx: Return of Xander Cage",
#       "Geostorm",
#       "The Fate of the Furious",
#       "The Mummy",
#       "Transformers: The Last Knight",
#       "Pirates of the Caribbean: Dead Men Tell No Tales",
#       "A Dog’s Purpose"]
# dict={'Name':Name,
#       'Popularity':Popularity,
#       'Rate':Rate}
# IMDb=pd.DataFrame(dict)
# IMDb
# Name=["xXx: Return of Xander Cage",
#       "Geostorm",
#       "The Fate of the Furious",
#       "The Mummy",
#       "Transformers: The Last Knight",
#       "Pirates of the Caribbean: Dead Men Tell No Tales",
#       "A Dog’s Purpose"]
# dict={'Name':Name,
#       'IMDbPopularity':Popularity,
#       'IMDbRate':Rate}
# Rating=pd.DataFrame(dict)
# Rating
# Name=["xXx: Return of Xander Cage",
#       "Geostorm",
#       "The Fate of the Furious",
#       "The Mummy",
#       "Transformers: The Last Knight",
#       "Pirates of the Caribbean: Dead Men Tell No Tales",
#       "A Dog’s Purpose"]
# dict={'Name':Name,
#       'IMDbPopularity':Popularity,
#       'IMDbRate':Rate}
# dict=[["Name",'IMDbPopularity','IMDbRate']]
# Rating=pd.DataFrame(dict)
# Rating
# Name=["xXx: Return of Xander Cage",
#       "Geostorm",
#       "The Fate of the Furious",
#       "The Mummy",
#       "Transformers: The Last Knight",
#       "Pirates of the Caribbean: Dead Men Tell No Tales",
#       "A Dog’s Purpose"]
# dict={'Name':Name,
#       'IMDbPopularity':Popularity,
#       'IMDbRate':Rate}
# Rating=pd.DataFrame(dict)
# Rating=Rating[["Name",'IMDbPopularity','IMDbRate']]
# Rating
# # add douban rating
# Rating['DoubanRate']=[5.6,6,8.3,7,4.7,4.8,7.2,7.7]
# # add douban rating
# Rating['DoubanRate']=[5.6,6,7,4.7,4.8,7.2,7.7]
# # add douban rating
# Rating['DoubanRate']=[5.6,6,7,4.7,4.8,7.2,7.7]
# Rating
# # add douban rating
# Rating['DoubanRate']=[5.6,6,7,4.7,4.8,7.2,7.7]
# Rating['ChineseBoxOfficeRank']=[13,38,2,25,7,11,26]
# Rating['AmericanBoxOfficeRank']=[60,75,12,39,25,18,44]
# Rating['WorldwideBoxOfficeRank']=[28,43,3,22,16,46]
# Rating
# # add douban rating
# Rating['DoubanRate']=[5.6,6,7,4.7,4.8,7.2,7.7]
# Rating['ChineseBoxOfficeRank']=[13,38,2,25,7,11,26]
# Rating['AmericanBoxOfficeRank']=[60,75,12,39,25,18,44]
# Rating['WorldwideBoxOfficeRank']=[28,43,3,22,16,11,46]
# Rating
# history

# %%
def myfun(urlbase):
    #urlbase = "https://www.the-numbers.com/person/25200401-D-J-Caruso#tab=summary"
    want1= requests.get(urlbase)
    want2 =want1.text
    want3 =BeautifulSoup(want2,'lxml-xml')
    want4=want3.find_all(name='span',attrs={'itemprop':'ratingValue'})
    want5=want4[0].text
    want6=want3.find_all(name='span',attrs={'class':'subText'})
    want7=want6[2].text.strip()
    want8=re.split(r"\n",want7)
    return want8,want5

# %% [markdown]
# the order is also according to the original table the porblem I have here is that I cannot delete /n

# %%
link=["http://www.imdb.com/title/tt1293847/",
      "http://www.imdb.com/title/tt1981128/",
      "http://www.imdb.com/title/tt4630562/",
      "http://www.imdb.com/title/tt2345759/",
      "http://www.imdb.com/title/tt3371366/?ref_=fn_al_tt_1",
      "http://www.imdb.com/title/tt3731562/?ref_=fn_al_tt_1",
      "http://www.imdb.com/title/tt1753383/?ref_=fn_al_tt_1"]
Popularity=[]
Rate=[]
for l in link:
    x=myfun(l)
    p=x[0][0]
    r=x[1]
    Popularity.append(p)
    Rate.append(r)

# %%
Name=["xXx: Return of Xander Cage",
      "Geostorm",
      "The Fate of the Furious",
      "The Mummy",
      "Transformers: The Last Knight",
      "Kong: Skull Island",
      "A Dog’s Purpose"]
dict={'Name':Name,
      'IMDbPopularity':Popularity,
      'IMDbRate':Rate}
Rating=pd.DataFrame(dict)
Rating=Rating[["Name",'IMDbPopularity','IMDbRate']]
Rating
# Out:
#                             Name IMDbPopularity IMDbRate
# 0     xXx: Return of Xander Cage            174      5.2
# 1                       Geostorm             97      5.4
# 2        The Fate of the Furious            148      6.7
# 3                      The Mummy             61      5.5
# 4  Transformers: The Last Knight            177      5.2
# 5             Kong: Skull Island            192      6.7
# 6                A Dog’s Purpose            914      6.9

# %%
# add douban rating
Rating['DoubanRate']=[5.6,6,7,4.7,4.8,7.8,7.7]
Rating['ChineseBoxOfficeRank']=[13,38,2,25,7,9,26]
Rating['AmericanBoxOfficeRank']=[60,75,12,39,25,19,44]
Rating['WorldwideBoxOfficeRank']=[28,43,3,22,16,21,46]
Rating
# Out:
#                             Name IMDbPopularity IMDbRate  DoubanRate  \
# 0     xXx: Return of Xander Cage            174      5.2         5.6
# 1                       Geostorm             97      5.4         6.0
# 2        The Fate of the Furious            148      6.7         7.0
# 3                      The Mummy             61      5.5         4.7
# 4  Transformers: The Last Knight            177      5.2         4.8
# 5             Kong: Skull Island            192      6.7         7.2
# 6                A Dog’s Purpose            914      6.9         7.7
#
#    ChineseBoxOfficeRank  AmericanBoxOfficeRank  WorldwideBoxOfficeRank
# 0                    13                     60                      28
# 1                    38                     75                      43
# 2                     2                     12                       3
# 3                    25                     39                      22
# 4                     7                     25                      16
# 5                    11                     18                      11
# 6                    26                     44                      46
